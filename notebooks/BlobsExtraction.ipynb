# %% [markdown]
# # ENAP (droneimagestorage)

# %% [markdown]
# ## 1. Download blobs

# %%
dateDir = '20201024'
outputDir = '../datasets/source_dataset'

# !python ../dataset_utils/blob_ops.py --dateDir {dateDir} --outputDir {outputDir} --op DOWNLOAD_BLOBS_AS_ONE_JSON
# Out:
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...

# %% [markdown]
# ## 2. Data filtering

# %%
filePath = '../datasets/source_dataset/'+dateDir+'/viaJsonFile_ORIGINAL.json'

# !python ../dataset_utils/data_ops.py --op FILTER_CLASSES --filePath {filePath} --justMaq True
# Out:
# Deleting image at idx 0
# Deleting image at idx 1
# Deleting image at idx 2
# Deleting image at idx 3
# Deleting image at idx 4
# Deleting image at idx 5
# Deleting image at idx 6
# Deleting image at idx 7
# Deleting image at idx 8
# Deleting image at idx 9
# Deleting image at idx 10
# Deleting image at idx 11
# Deleting image at idx 12
# Deleting image at idx 13
# Deleting image at idx 14
# Deleting image at idx 15
# Deleting image at idx 16
# Deleting image at idx 17
# Deleting image at idx 18
# Deleting image at idx 19
# Deleting image at idx 20
# Deleting image at idx 21
# Deleting image at idx 23
# Deleting image at idx 24
# Deleting image at idx 26
# Deleting image at idx 27
# Deleting image at idx 28
# Deleting image at idx 29
# Deleting image at idx 30
# Deleting image at idx 31
# Deleting image at idx 32
# Deleting image at idx 33
# Deleting image at idx 34
# Deleting image at idx 36
# Deleting image at idx 37
# Deleting image at idx 38
# Deleting image at idx 39
# ...

# %% [markdown]
# # SONACOL (plataformamonitoreo)

# %% [markdown]
# ## 1. Formatting as VIA

# %%
dataVersion = 'v4'
filePath = '../datasets/alertas-1598994498788.json'
outputDir = os.path.join('../datasets/data', dataVersion, '20200831')
# !python ../dataset_utils/data_ops.py --op FORMAT_SONACOL_AS_VIA --dataVersion {dataVersion} --filePath {filePath} --outputDir {outputDir} --justMaq True
# Out:
# windows.net/airesults/2020-08-31_16-18-46_GPS.jpg
# Keeping mark with class: Tractor
# Omitting image at idx 176: https://plataformamonitoreo.blob.core.windows.net/airesults/2020-08-31_16-19-22_GPS.jpg
# Keeping mark with class: Maquinaria
# Keeping mark with class: Tractor
# Keeping mark with class: Maquinaria
# Keeping mark with class: Maquinaria
# Keeping mark with class: Camión
# Keeping mark with class: Camión
# Keeping mark with class: Vehículo
# Keeping mark with class: Maquinaria
# Keeping mark with class: Vehículo
# Keeping mark with class: Camión
# Keeping mark with class: Tractor
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Vehículo
# Keeping mark with class: Tractor
# Keeping mark with class: Maquinaria
# Keeping mark with class: Tractor
# ...

# %% [markdown]
# # Download blobs from list

# %%
inputFile = 'D:/Development/ENAP/aerialnet/datasets/false_positives/data.txt'
outputFile = 'D:/Development/ENAP/aerialnet/datasets/false_positives/september.json'

# !python ../dataset_utils/blob_ops.py --inputFile {inputFile} --outputFile {outputFile} --op DOWNLOAD_BLOBS_AS_ONE_JSON_FROM_LIST
# Out:
# ^C
