# %%
import numpy as np

from timeit import default_timer as timer

import cv2 
from matplotlib import pyplot as plt

from aerialnet.utils.image import render
import json

# %%
with open('alertas_07-08-2020.json', 'r') as jFile:
    jsonData = json.load(jFile)

jsonData['data']['alerts']['total']
data = jsonData['data']['alerts']['data']

# %%
for alert in data:
    print(alert['file']['url'])
# Out:
# ows.net/dronblob/fran203175@gmail.com/2020/08/07/2020-08-07_15:58:10-4716687-DJI_0131.jpg
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0378.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0377.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0375.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0374.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0371.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0362.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/luis.pirela@kauel.com/2020/08/07/DJI_0361.JPG
# https://droneimagesstorage.blob.core.windows.net/dronblob/antoniojosesolano2012@gmail.com/2020/08/07/2020-08-07_15:27:54-3681542-DJI_0226.jpg
# ...
